# %%
import numpy as np
import pandas as pd

# %%
bat = pd.read_csv("D:/Programming in Data Science/odi-batting.csv")
bat.head()
# Out:
#        Country            Player   Runs  ScoreRate  MatchDate  \
# 0  Afghanistan  Mohammad Shahzad  118.0      97.52  2-16-2010
# 1  Afghanistan  Mohammad Shahzad  110.0      99.09   9-1-2009
# 2  Afghanistan  Mohammad Shahzad  100.0     138.88  8-16-2010
# 3  Afghanistan  Mohammad Shahzad   82.0      75.92  7-10-2010
# 4  Afghanistan  Mohammad Shahzad   57.0     100.00   7-1-2010
#
#                   Ground       Versus  \
# 0     Sharjah CA Stadium       Canada
# 1             VRA Ground  Netherlands
# 2  Cambusdoon New Ground     Scotland
# 3            Hazelaarweg  Netherlands
# 4    Sportpark Westvliet       Canada
#
#                                                 URL
# 0  ../Matches/MatchScorecard_ODI.asp?MatchCode=3087
# 1  ../Matches/MatchScorecard_ODI.asp?MatchCode=3008
# 2  ../Matches/MatchScorecard_ODI.asp?MatchCode=3164
# 3  ../Matches/MatchScorecard_ODI.asp?MatchCode=3153
# 4  ../Matches/MatchScorecard_ODI.asp?MatchCode=3135

# %%
bat = bat.set_index(['Player'])
bat_group = bat.groupby(level = ['Player'])

# %%
bat_group.groups
cou = bat_group.count()
cou
# Out:
#                        Country  Runs  ScoreRate  MatchDate  Ground  Versus  \
# Player
# Aamer Hanif                  4     4          4          4       4       4
# Aamer Malik                 23    23         23         23      23      23
# Aamir Nazir                  3     3          3          3       3       3
# Aamir Sohail               156   155        155        156     156     156
# Aaqib Javed                 51    51         51         51      51      51
# Aaron J Redmond              6     6          6          6       6       6
# Aashish R Kapoor             6     6          6          6       6       6
# Aasif Y Karim               24    24         24         24      24      24
# Aavishkar M Salvi            3     3          3          3       3       3
# Abdool M Samad              27    27         27         27      27      27
# Abdul Jabbar                 2     2          2          2       2       2
# ...

# %%
# Out:
#                           Country   Runs  ScoreRate   MatchDate  \
# Player
# Mohammad Shahzad      Afghanistan  118.0      97.52   2-16-2010
# Mohammad Shahzad      Afghanistan  110.0      99.09    9-1-2009
# Mohammad Shahzad      Afghanistan  100.0     138.88   8-16-2010
# Mohammad Shahzad      Afghanistan   82.0      75.92   7-10-2010
# Mohammad Shahzad      Afghanistan   57.0     100.00    7-1-2010
# Mohammad Shahzad      Afghanistan   55.0      87.30    7-7-2010
# Mohammad Shahzad      Afghanistan   37.0      80.43   10-9-2010
# Mohammad Shahzad      Afghanistan   34.0      77.27    7-9-2010
# Mohammad Shahzad      Afghanistan   20.0      90.90    7-5-2010
# Mohammad Shahzad      Afghanistan   16.0      57.14   8-30-2009
# Mohammad Shahzad      Afghanistan   11.0     100.00   8-17-2010
# Mohammad Shahzad      Afghanistan    8.0      80.00    8-9-2011
# Mohammad Shahzad      Afghanistan    2.0      50.00    7-3-2010
# ...
